# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
hw3=pd.read_csv("/content/mtcars.csv")

# %%
print(hw3)
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
hw3.shape
# Out:
# (32, 11)

# %%
hw3.axes
# Out:
# [RangeIndex(start=0, stop=32, step=1),
#  Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#         'carb'],
#        dtype='object')]

# %%
hw3.dtypes
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
hw3.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
hw3.describe()
# Out:
#              mpg        cyl        disp  ...         am       gear     carb
# count  32.000000  32.000000   32.000000  ...  32.000000  32.000000  32.0000
# mean   20.090625   6.187500  230.721875  ...   0.406250   3.687500   2.8125
# std     6.026948   1.785922  123.938694  ...   0.498991   0.737804   1.6152
# min    10.400000   4.000000   71.100000  ...   0.000000   3.000000   1.0000
# 25%    15.425000   4.000000  120.825000  ...   0.000000   3.000000   2.0000
# 50%    19.200000   6.000000  196.300000  ...   0.000000   4.000000   2.0000
# 75%    22.800000   8.000000  326.000000  ...   1.000000   4.000000   4.0000
# max    33.900000   8.000000  472.000000  ...   1.000000   5.000000   8.0000
#
# [8 rows x 11 columns]

# %%
hw3.groupby(['cyl','disp'])[['mpg']].describe()
# Out:
#             mpg
#           count  mean       std   min    25%   50%    75%   max
# cyl disp
# 4   71.1    1.0  33.9       NaN  33.9  33.90  33.9  33.90  33.9
#     75.7    1.0  30.4       NaN  30.4  30.40  30.4  30.40  30.4
#     78.7    1.0  32.4       NaN  32.4  32.40  32.4  32.40  32.4
#     79.0    1.0  27.3       NaN  27.3  27.30  27.3  27.30  27.3
#     95.1    1.0  30.4       NaN  30.4  30.40  30.4  30.40  30.4
#     108.0   1.0  22.8       NaN  22.8  22.80  22.8  22.80  22.8
#     120.1   1.0  21.5       NaN  21.5  21.50  21.5  21.50  21.5
#     120.3   1.0  26.0       NaN  26.0  26.00  26.0  26.00  26.0
#     121.0   1.0  21.4       NaN  21.4  21.40  21.4  21.40  21.4
#     140.8   1.0  22.8       NaN  22.8  22.80  22.8  22.80  22.8
#     146.7   1.0  24.4       NaN  24.4  24.40  24.4  24.40  24.4
# 6   145.0   1.0  19.7       NaN  19.7  19.70  19.7  19.70  19.7
#     160.0   2.0  21.0  0.000000  21.0  21.00  21.0  21.00  21.0
# ...

# %%
hw3[hw3['cyl']>3]
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
hw3['cyl']>4
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29     True
# 30     True
# 31    False
# Name: cyl, dtype: bool

# %%
hw3.skew(
)
# Out:
# mpg     0.672377
# cyl    -0.192261
# disp    0.420233
# hp      0.799407
# drat    0.292780
# wt      0.465916
# qsec    0.406347
# vs      0.264542
# am      0.400809
# gear    0.582309
# carb    1.157091
# dtype: float64

# %%
hw3.kurtosis()
# Out:
# mpg    -0.022006
# cyl    -1.762794
# disp   -1.067523
# hp      0.275212
# drat   -0.450432
# wt      0.416595
# qsec    0.864931
# vs     -2.063273
# am     -1.966550
# gear   -0.895292
# carb    2.020059
# dtype: float64

# %%
hw3.ndim
# Out:
# 2

# %%
hw3.values
# Out:
# array([[ 21.   ,   6.   , 160.   , 110.   ,   3.9  ,   2.62 ,  16.46 ,
#           0.   ,   1.   ,   4.   ,   4.   ],
#        [ 21.   ,   6.   , 160.   , 110.   ,   3.9  ,   2.875,  17.02 ,
#           0.   ,   1.   ,   4.   ,   4.   ],
#        [ 22.8  ,   4.   , 108.   ,  93.   ,   3.85 ,   2.32 ,  18.61 ,
#           1.   ,   1.   ,   4.   ,   1.   ],
#        [ 21.4  ,   6.   , 258.   , 110.   ,   3.08 ,   3.215,  19.44 ,
#           1.   ,   0.   ,   3.   ,   1.   ],
#        [ 18.7  ,   8.   , 360.   , 175.   ,   3.15 ,   3.44 ,  17.02 ,
#           0.   ,   0.   ,   3.   ,   2.   ],
#        [ 18.1  ,   6.   , 225.   , 105.   ,   2.76 ,   3.46 ,  20.22 ,
#           1.   ,   0.   ,   3.   ,   1.   ],
#        [ 14.3  ,   8.   , 360.   , 245.   ,   3.21 ,   3.57 ,  15.84 ,
#           0.   ,   0.   ,   3.   ,   4.   ],
#        [ 24.4  ,   4.   , 146.7  ,  62.   ,   3.69 ,   3.19 ,  20.   ,
#           1.   ,   0.   ,   4.   ,   2.   ],
# ...

# %%
hw3.count()
# Out:
# mpg     32
# cyl     32
# disp    32
# hp      32
# drat    32
# wt      32
# qsec    32
# vs      32
# am      32
# gear    32
# carb    32
# dtype: int64
